# %% [markdown]
# This notebook is a solution to Advent of Code 2022 Day 19: https://adventofcode.com/2022/day/19
#
# I thought this was particularly interesting because it could be solved with integer optimization, below is my solution using the "pyomo" package.
#
# First, the instructions can be encoded in a matrix to be used programatically. This "Cost Matrix" looks like this:
#
# {
# 'ore': {'ore': 3, 'clay': 0, 'obsidian': 0},
# 'clay': {'ore': 3, 'clay': 0, 'obsidian': 0},
# 'obsidian': {'ore': 2, 'clay': 19, 'obsidian': 0},
# 'geode': {'ore': 2, 'clay': 0, 'obsidian': 12}
# }
#
#  [ 3.  3.  2.  2.]
#  [ 0.  0. 19.  0.]
#  [ 0.  0.  0. 12.]
#  [ 0.  0.  0.  0.]
#
# where each row and column represent an input (here it's ore, clay, obsidian, geode in that order), and the number for a given row and column tells how much [row] it takes to produce [column]. For example, the 19 says it takes 19 clay to produce an obsidian.
#
# While solving the problem, we are primarily tracking the number of machines we have per timestep. This has a number of advantages when building our constraints:
#  - Machines are our primary costs.
#  - Since each machine can produce 1 x per minute, we can easily calculate how many x's we've produced by cumulative-summing our x-machines across time (and then subtracting our final count of x-machines because they don't produce x on the timestep they are built).
#
# This is similarly represented by a matrix with columns being ore, clay, obsidian, geode again and each row representing a timestep. A realistic machine-matrix is shown below:
#
#    [[1., 0., 0., 0.],
#     [1., 0., 0., 0.],
#     [1., 0., 0., 0.],
#     [2., 0., 0., 0.],
#     [2., 0., 0., 0.],
#     [2., 1., 0., 0.],
#     [2., 1., 0., 0.],
#     [2., 2., 0., 0.],
#     [2., 3., 0., 0.],
#     [2., 3., 0., 0.],
#     [2., 4., 0., 0.],
#     [2., 5., 0., 0.],
#     [2., 5., 0., 0.],
#     [2., 6., 0., 0.],
#     [2., 6., 1., 0.],
#     [2., 6., 1., 0.],
#     [2., 7., 1., 0.],
#     [2., 8., 1., 0.],
#     [2., 8., 2., 0.],
#     [2., 8., 3., 0.],
#     [2., 9., 3., 0.],
#     [2., 9., 3., 0.],
#     [2., 9., 3., 1.],
#     [2., 9., 3., 1.]]
#
# It starts at time 1, so for example time 6 (row 6) shows that we have 2 ore machines and 1 clay machine
#
# The point of the transformations above is to give structure to the solver. We are going to tell the solver to maximize the number of geodes produced by minute 24. However, doing so without any constraints will result in an unbounded solution - after all the solver doesn't inherently know that we can't build 2^64-1 geode machines in the first timestep. It doesn't even know that we start with 1 ore machine, so it could fill in whatever it wants in the machine matrix!
#
# So we must build some constraints:
#
#  - "initial_state_constraint". Simply ensures that we start with 1 ore machine and nothing else. This is implemented by ensuring that if we are on the first timestep, the ore position must be 1 and the rest must be 0.
#
#  - "net_ore_constraint". We can calculate the total cost of our machines for any given timestep, and we can calculate the total number of various ore's we've gathered. Thus, our solutions are only valid if, for every timestep, our total cost is less than or equal to our total production. Basically, we can't build machines if we don't have the ores necessary.
#
#  - "only_machine_per_minute_constraint". The original problem dictates we can only build 1 machine per timestep. This can be solved by summing our machine count for every timestep, and ensuring that between timesteps, the count differs by at most 1.
#
#  - "monotonically_increasing_machines_constraint". The original problem only allows us to buy machines. Note that in our net_ore_constraint, we calculate the cost and production of our machines/ores. The issue is that the solver may try to sell machines to fulfill the constraint, e.g. maybe for some timestep it could be optimal to sell a obsidian machine, and buy a ore and a clay machine, and have the net cost still be fulfilled. This constraint avoid that problem. The implementation is similar to the above, we must ensuring that the total number of machines between each timestep either stays the same or increases).
#
# Our objective function is maximizing the total number of geodes we produce. With regards to our machine matrix, this is done by summing the total amount of geode machines we have for each timestep (since the machine matrix keeps track of the cumulative number of each machine, and since each machine produces one thing per second) and subtracting our final count of them (since we don't get the results of the last timestep).
#
# It turns out that this is enough to solve the problem! The solver will try to maximize our objective function subject to our constraints. The results are stored in the model object, and with a little bit of extraction work we can get the final objective function value, as well as the machine matrix. As a bonus, part 2 is just running it for 32 timesteps, which is a trivial input to our model.
#
# I've always found these sorts of solvers interesting because the problem is tenable logically but totally impossible to solve by hand. I've described the logic to setting up the problem above, and the conversion to code is not too complicated, but the actual problem is gargantuan. The net_ore_constraint, for example, can be described logically, but is actually expressed as 92 (24*4) separate equations that must be satisfied: for each timestep, and for each ore-type, the amount we've produced for that ore-type must equal the amount we've used of that ore-type. There are 215 constraints for the 24 timestep solve, and you could see how the number of constraints could balloon if you had dozens of ores for hundreds of timesteps instead.
#
# But it's always fun to bust out the linear programming. I don't often find a use for it but it's nice to brush up on.
#
#
# Additional details:
# 1. Below is an example of one part of the net_ore_constraint:
# (5, 0): machine_time_matrix[0,0] + machine_time_matrix[1,0] + machine_time_matrix[2,0] + machine_time_matrix[3,0] + 1 - ((machine_time_matrix[5,0] - machine_time_matrix[0,0])*4.0 + (machine_time_matrix[5,1] - machine_time_matrix[0,1])*2.0 + (machine_time_matrix[5,2] - machine_time_matrix[0,2])*3.0 + (machine_time_matrix[5,3] - machine_time_matrix[0,3])*2.0))
#
# The indices here are 0-indexed, so (5, 0) translates to timestep 6 and ores.
#
# Our total ore production is [machine_time_matrix[0,0] + machine_time_matrix[1,0] + machine_time_matrix[2,0] + machine_time_matrix[3,0] + 1]. Note that it's an implementation detail that we go up to 3 (timestep 4) only. The problem specifies that it takes 1 timestep to actually build the machine, which is equivalent to using 1 less day's worth of production and instantly building the machine.
#
# Our costs are:
# (machine_time_matrix[5,0] - machine_time_matrix[0,0])*4.0 +
# (machine_time_matrix[5,1] - machine_time_matrix[0,1])*2.0 +
# (machine_time_matrix[5,2] - machine_time_matrix[0,2])*3.0 +
# (machine_time_matrix[5,3] - machine_time_matrix[0,3])*2.0
#
# Which you can see is just the number of machines we've added since the start, multiplied by their respective ore costs. So net_ore_constraint (5, 0) is ensuring that the ore we've produced up until timestep 6 is sufficient to have covered our total ore spent on machines.

# %%
# Set-up + parsing data

inp = """Blueprint 1:
  Each ore robot costs 4 ore.
  Each clay robot costs 2 ore.
  Each obsidian robot costs 3 ore and 14 clay.
  Each geode robot costs 2 ore and 7 obsidian.

Blueprint 2:
  Each ore robot costs 2 ore.
  Each clay robot costs 3 ore.
  Each obsidian robot costs 3 ore and 8 clay.
  Each geode robot costs 3 ore and 12 obsidian."""
inp = inp.split("\n\n")

inp = """Blueprint 1: Each ore robot costs 3 ore. Each clay robot costs 3 ore. Each obsidian robot costs 2 ore and 19 clay. Each geode robot costs 2 ore and 12 obsidian.
Blueprint 2: Each ore robot costs 3 ore. Each clay robot costs 3 ore. Each obsidian robot costs 3 ore and 19 clay. Each geode robot costs 2 ore and 9 obsidian.
Blueprint 3: Each ore robot costs 2 ore. Each clay robot costs 3 ore. Each obsidian robot costs 3 ore and 17 clay. Each geode robot costs 3 ore and 10 obsidian.
Blueprint 4: Each ore robot costs 4 ore. Each clay robot costs 4 ore. Each obsidian robot costs 2 ore and 14 clay. Each geode robot costs 4 ore and 15 obsidian.
Blueprint 5: Each ore robot costs 4 ore. Each clay robot costs 4 ore. Each obsidian robot costs 2 ore and 12 clay. Each geode robot costs 3 ore and 15 obsidian.
Blueprint 6: Each ore robot costs 4 ore. Each clay robot costs 4 ore. Each obsidian robot costs 4 ore and 8 clay. Each geode robot costs 3 ore and 19 obsidian.
Blueprint 7: Each ore robot costs 4 ore. Each clay robot costs 4 ore. Each obsidian robot costs 4 ore and 7 clay. Each geode robot costs 4 ore and 17 obsidian.
Blueprint 8: Each ore robot costs 4 ore. Each clay robot costs 4 ore. Each obsidian robot costs 4 ore and 14 clay. Each geode robot costs 3 ore and 16 obsidian.
Blueprint 9: Each ore robot costs 2 ore. Each clay robot costs 4 ore. Each obsidian robot costs 2 ore and 16 clay. Each geode robot costs 2 ore and 9 obsidian.
Blueprint 10: Each ore robot costs 4 ore. Each clay robot costs 4 ore. Each obsidian robot costs 4 ore and 5 clay. Each geode robot costs 3 ore and 7 obsidian.
Blueprint 11: Each ore robot costs 2 ore. Each clay robot costs 4 ore. Each obsidian robot costs 3 ore and 14 clay. Each geode robot costs 4 ore and 9 obsidian.
Blueprint 12: Each ore robot costs 3 ore. Each clay robot costs 4 ore. Each obsidian robot costs 3 ore and 16 clay. Each geode robot costs 3 ore and 14 obsidian.
Blueprint 13: Each ore robot costs 2 ore. Each clay robot costs 3 ore. Each obsidian robot costs 3 ore and 18 clay. Each geode robot costs 2 ore and 19 obsidian.
Blueprint 14: Each ore robot costs 3 ore. Each clay robot costs 3 ore. Each obsidian robot costs 2 ore and 13 clay. Each geode robot costs 3 ore and 12 obsidian.
Blueprint 15: Each ore robot costs 3 ore. Each clay robot costs 3 ore. Each obsidian robot costs 3 ore and 16 clay. Each geode robot costs 3 ore and 9 obsidian.
Blueprint 16: Each ore robot costs 3 ore. Each clay robot costs 3 ore. Each obsidian robot costs 3 ore and 17 clay. Each geode robot costs 4 ore and 8 obsidian.
Blueprint 17: Each ore robot costs 2 ore. Each clay robot costs 2 ore. Each obsidian robot costs 2 ore and 17 clay. Each geode robot costs 2 ore and 10 obsidian.
Blueprint 18: Each ore robot costs 2 ore. Each clay robot costs 3 ore. Each obsidian robot costs 3 ore and 16 clay. Each geode robot costs 2 ore and 11 obsidian.
Blueprint 19: Each ore robot costs 4 ore. Each clay robot costs 4 ore. Each obsidian robot costs 4 ore and 12 clay. Each geode robot costs 3 ore and 8 obsidian.
Blueprint 20: Each ore robot costs 3 ore. Each clay robot costs 4 ore. Each obsidian robot costs 3 ore and 12 clay. Each geode robot costs 3 ore and 17 obsidian.
Blueprint 21: Each ore robot costs 3 ore. Each clay robot costs 3 ore. Each obsidian robot costs 2 ore and 7 clay. Each geode robot costs 2 ore and 9 obsidian.
Blueprint 22: Each ore robot costs 2 ore. Each clay robot costs 4 ore. Each obsidian robot costs 3 ore and 17 clay. Each geode robot costs 4 ore and 20 obsidian.
Blueprint 23: Each ore robot costs 4 ore. Each clay robot costs 3 ore. Each obsidian robot costs 2 ore and 19 clay. Each geode robot costs 3 ore and 10 obsidian.
Blueprint 24: Each ore robot costs 4 ore. Each clay robot costs 4 ore. Each obsidian robot costs 3 ore and 9 clay. Each geode robot costs 3 ore and 7 obsidian.
Blueprint 25: Each ore robot costs 2 ore. Each clay robot costs 3 ore. Each obsidian robot costs 3 ore and 14 clay. Each geode robot costs 3 ore and 19 obsidian.
Blueprint 26: Each ore robot costs 3 ore. Each clay robot costs 3 ore. Each obsidian robot costs 3 ore and 16 clay. Each geode robot costs 3 ore and 20 obsidian.
Blueprint 27: Each ore robot costs 3 ore. Each clay robot costs 4 ore. Each obsidian robot costs 4 ore and 19 clay. Each geode robot costs 4 ore and 11 obsidian.
Blueprint 28: Each ore robot costs 4 ore. Each clay robot costs 3 ore. Each obsidian robot costs 3 ore and 11 clay. Each geode robot costs 4 ore and 7 obsidian.
Blueprint 29: Each ore robot costs 3 ore. Each clay robot costs 3 ore. Each obsidian robot costs 3 ore and 8 clay. Each geode robot costs 2 ore and 12 obsidian.
Blueprint 30: Each ore robot costs 4 ore. Each clay robot costs 4 ore. Each obsidian robot costs 4 ore and 8 clay. Each geode robot costs 2 ore and 15 obsidian."""
inp = inp.split('\n')

split = []
for test in inp:
    test = test.replace(':', ':\n  ')
    test = test.replace('.', '.\n  ')
    test = test[:-3]
    split.append(test)
inp = split

import re

def parse_blueprint(blueprint):
    # Dictionary to hold the parsed costs
    robot_costs = {}

    # Split the blueprint string into lines
    lines = blueprint.strip().split('\n')

    # Regular expression to match the lines with cost details
    cost_pattern = re.compile(r'Each (\w+) robot costs (\d+) ore(?: and (\d+) clay)?(?: and (\d+) obsidian)?.')

    # Parse each line
    for line in lines:
        match = cost_pattern.match(line.strip())
        if match:
            # Extract robot type and costs
            robot_type = match.group(1)
            ore_cost = int(match.group(2))
            clay_cost = int(match.group(3)) if match.group(3) else 0
            obsidian_cost = int(match.group(4)) if match.group(4) else 0

            # Add to the dictionary
            robot_costs[robot_type] = {'ore': ore_cost, 'clay': clay_cost, 'obsidian': obsidian_cost}

    return robot_costs

blueprints = []
for blueprint in inp:
    blueprints.append(parse_blueprint(blueprint))

# %%
from pyomo.core import *
from pyomo.opt import SolverFactory, SolverStatus, TerminationCondition
import pyomo.environ as pe

import numpy as np

import logging
logging.getLogger('pyomo.core').setLevel(logging.INFO)

solver = 'glpk'
opt = SolverFactory(solver)

# %%
# Objective function is reducing the sum of all elements in the array
def obj_func(model):
    # Maximize amount of geodes or minimize the negative amount of geodes
    return sum([model.machine_time_matrix[i, 3] for i in model.I]) - model.machine_time_matrix[model.i, 3]


def net_ore_constraint(model, i, jj):
#     if i == 0:
#         return Constraint.Skip
    total_ores = [sum([model.machine_time_matrix[ii, j] for ii in range(i-1)]) for j in model.J]
    total_ores[0] += 1  #  Start at minute 1
#     total_ores[0] += model.blueprint_array[0, 0]
    
    machines_built = [model.machine_time_matrix[i, j] - model.machine_time_matrix[0, j] for j in model.J]
#     machines_built = [model.machine_time_matrix[i, j] for j in model.J]
    costs = [sum([(machines_built[k] * model.blueprint_array[j, k]) for k in model.J]) for j in model.J]
    return total_ores[jj] - costs[jj] >= 0


def only_machine_per_minute_constraint(model, i):
    if i == min(model.I):  # No constraint needed for the first
        return Constraint.Skip
    current_machines = sum([model.machine_time_matrix[i, j] for j in model.J])
    prev_machines = sum([model.machine_time_matrix[i-1, j] for j in model.J])
    
    return current_machines - prev_machines <= 1


def monotonically_increasing_machines_constraint(model, i, j):
    if i == max(model.I):  # No constraint needed for the last row
        return Constraint.Skip
    # Else, ensure that the value in the next row is greater than or equal
    return model.machine_time_matrix[i+1, j] >= model.machine_time_matrix[i, j]


def initial_state_constraint(model, j):
    if j == 0:
        return model.machine_time_matrix[0, j] == 1
    else:
        return model.machine_time_matrix[0, j] == 0
    
def test_constraint(model, j):
    if j == 0:
        return model.machine_time_matrix[2, j] == 1
    elif j == 1:
        return model.machine_time_matrix[2, j] == 1
    else:
        return model.machine_time_matrix[2, j] == 0
    
    
def all_integers_constraint(model, i, j):
    return model.machine_time_matrix[i, j].is_integer()


def array_to_dict_2d(array):
    dct = dict()
    
    for i in range(len(array)):
        for j in range(len(array[0])):
            dct[i, j] = float(array[i, j])
    return dct


def array_to_dict_1d(array):
    dct = dict()
    
    for i in range(len(array)):
        dct[i] = float(array[i])
    return dct


class ModelFactory(object):
    def __init__(self, machine_time_matrix, blueprint_array):
        self.machine_time_matrix = machine_time_matrix
        self.blueprint_array = blueprint_array
        
        self.LENGTH_I, self.LENGTH_J = self.machine_time_matrix.shape
        
    def create_model(self):
        model = ConcreteModel()
        model._blueprint_array = self.blueprint_array

        model.i = Param(within=NonNegativeIntegers, default=self.LENGTH_I-1)
        model.j = Param(within=NonNegativeIntegers, default=self.LENGTH_J-1)

        model.I = RangeSet(0, model.i)
        model.J = RangeSet(0, model.j)
        
        model.blueprint_dim = RangeSet(0, 3)

        model.machine_time_matrix = Var(model.I, model.J, 
                initialize=array_to_dict_2d(self.machine_time_matrix), within=NonNegativeIntegers)
        model.blueprint_array = Param(model.blueprint_dim, model.blueprint_dim, 
                initialize=array_to_dict_2d(self.blueprint_array), mutable=False)
        
        # OBJECTIVE + CONSTRAINTS
        model.obj = Objective(rule=obj_func, sense=maximize)
        model.monotonically_increasing_machines_constraint = Constraint(model.I, model.J, rule=monotonically_increasing_machines_constraint)
        model.net_ore_constraint = Constraint(model.I, model.J, rule = net_ore_constraint)
        model.initial_state_constraint = Constraint(model.J, rule = initial_state_constraint)
        model.only_machine_per_minute_constraint = Constraint(model.I, rule = only_machine_per_minute_constraint)
        
#         model.test_constraint = Constraint(model.J, rule = test_constraint)
        return model

# %%
def solve_for_blueprint(blueprint, time, debug=False):
    machine_time_matrix = np.zeros((time, 4))
    machine_time_matrix[:, 0] = 1

    blueprint_array = np.zeros([4, 4])
    bp = blueprint

    mapping = {'ore': 0, 'clay': 1, 'obsidian': 2, 'geode': 3}
    for ore_col, cost_dict in bp.items():
        for ore_row, cost in cost_dict.items():
            blueprint_array[mapping[ore_row], mapping[ore_col]] = cost
    if debug:
        print(blueprint)
        print("Blueprint Cost Array:")
        print(blueprint_array)
        
    mf = ModelFactory(machine_time_matrix, blueprint_array)
    m = mf.create_model()
    result = opt.solve(m, tee=True)
    
    if debug:
        return m
    return value(m.obj)

import pandas as pd

def get_costs_and_prods(display, i):
    machines_built = display.loc[i] - display.loc[0]
    costs = (machines_built[1:].values * m._blueprint_array).sum(1)
    produced = display.values[:i, 1:].sum(0)
    
    return costs, produced


def get_display(m):
    display = np.zeros((m.i()+1, m.j()+2))
    for i in range(m.i()+1):
        for j in range(m.j()+2):
            if j == 0:
                display[i, j] = i+1
            else:
                display[i, j] = value(m.machine_time_matrix[i, j-1])
                
    display = pd.DataFrame(display, dtype=int)
#     display.columns = ["Time", "Ore", "Clay", "Obsidian", "Geode"]
    
    costs_prods = []
    for i in range(len(display)):
        costs, prods = get_costs_and_prods(display, i)
        costs_prods.append(np.concatenate([costs, prods]))

    cost_prod_array = np.vstack(costs_prods)
        
    df = pd.concat([display, pd.DataFrame(np.vstack(cost_prod_array))], axis=1)
    df.columns = ["Time", 
                  "Ore-Mach", "Clay-Mach", "Obsidian-Mach", "Geode-Mach", 
                  "Ore-Cost", "Clay-Cost", "Obsidian-Cost", "Geode-Cost",
                  "Ore-Prod", "Clay-Prod", "Obsidian-Prod", "Geode-Prod"]

    df = df.astype(int)
    
    df.loc[:, "Ore-Prod"] = df.loc[:, "Ore-Prod"] + 1
        
    return df

# %%
# m = solve_for_blueprint(blueprints[0], 24, True)
# m.net_ore_constraint.pprint()
# display = get_display(m)
# m.obj()
# display
# display.loc[:, ['Ore-Prod', 'Clay-Prod', 'Obsidian-Prod', 'Geode-Prod']].values - display.loc[:, ['Ore-Cost', 'Clay-Cost', 'Obsidian-Cost', 'Geode-Cost']].values

# %%
quality_level = []
for i, bp in enumerate(blueprints):
    quality_level.append((i+1) * solve_for_blueprint(bp, 24))
# Out:
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpsccqsaha.glpk.raw --wglp /tmp/tmpx380verc.glpk.glp --cpxlp
#  /tmp/tmp2g2jdsnt.pyomo.lp
# Reading problem data from '/tmp/tmp2g2jdsnt.pyomo.lp'...
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# 2514 lines were read
# Writing problem data to '/tmp/tmpx380verc.glpk.glp'...
# 2285 lines were written
# GLPK Integer Optimizer, v4.65
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# Preprocessing...
# 1 constraint coefficient(s) were reduced
# 130 rows, 61 columns, 758 non-zeros
# 61 integer variables, 7 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.900e+01  ratio =  1.900e+01
# GM: min|aij| =  3.806e-01  max|aij| =  2.628e+00  ratio =  6.904e+00
# EQ: min|aij| =  1.450e-01  max|aij| =  1.000e+00  ratio =  6.895e+00
# 2N: min|aij| =  1.250e-01  max|aij| =  1.500e+00  ratio =  1.200e+01
# Constructing initial basis...
# Size of triangular part is 130
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 130 rows, 61 columns, 758 non-zeros
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (5)
# *    93: obj =   5.456365928e+00 inf =   1.735e-15 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    93: mip =     not found yet <=              +inf        (1; 0)
# Solution found by heuristic: 0
# Solution found by heuristic: 1
# +   873: mip =   1.000000000e+00 <=     tree is empty   0.0% (0; 171)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.4 Mb (420403 bytes)
# Writing MIP solution to '/tmp/tmpsccqsaha.glpk.raw'...
# 321 lines were written
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmp4wv7al_y.glpk.raw --wglp /tmp/tmpxotgpmcc.glpk.glp --cpxlp
#  /tmp/tmph3n74nni.pyomo.lp
# Reading problem data from '/tmp/tmph3n74nni.pyomo.lp'...
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# 2514 lines were read
# Writing problem data to '/tmp/tmpxotgpmcc.glpk.glp'...
# 2285 lines were written
# GLPK Integer Optimizer, v4.65
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# Preprocessing...
# 1 constraint coefficient(s) were reduced
# 130 rows, 61 columns, 758 non-zeros
# 61 integer variables, 7 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.900e+01  ratio =  1.900e+01
# GM: min|aij| =  3.985e-01  max|aij| =  2.509e+00  ratio =  6.296e+00
# EQ: min|aij| =  1.596e-01  max|aij| =  1.000e+00  ratio =  6.267e+00
# 2N: min|aij| =  1.250e-01  max|aij| =  1.500e+00  ratio =  1.200e+01
# Constructing initial basis...
# Size of triangular part is 130
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 130 rows, 61 columns, 758 non-zeros
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (5)
# *    89: obj =   7.044106326e+00 inf =   8.129e-15 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    89: mip =     not found yet <=              +inf        (1; 0)
# +   411: >>>>>   2.000000000e+00 <=   2.000000000e+00   0.0% (20; 8)
# +   411: mip =   2.000000000e+00 <=     tree is empty   0.0% (0; 55)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.4 Mb (436003 bytes)
# Writing MIP solution to '/tmp/tmp4wv7al_y.glpk.raw'...
# 321 lines were written
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmprid4e1yv.glpk.raw --wglp /tmp/tmp6wcja8fh.glpk.glp --cpxlp
#  /tmp/tmpwcbhz0q1.pyomo.lp
# Reading problem data from '/tmp/tmpwcbhz0q1.pyomo.lp'...
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# 2514 lines were read
# Writing problem data to '/tmp/tmp6wcja8fh.glpk.glp'...
# 2285 lines were written
# GLPK Integer Optimizer, v4.65
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# Preprocessing...
# 1 constraint coefficient(s) were reduced
# 136 rows, 65 columns, 812 non-zeros
# 65 integer variables, 6 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.700e+01  ratio =  1.700e+01
# GM: min|aij| =  4.181e-01  max|aij| =  2.392e+00  ratio =  5.720e+00
# EQ: min|aij| =  1.781e-01  max|aij| =  1.000e+00  ratio =  5.616e+00
# 2N: min|aij| =  1.250e-01  max|aij| =  1.500e+00  ratio =  1.200e+01
# Constructing initial basis...
# Size of triangular part is 136
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 136 rows, 65 columns, 812 non-zeros
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (7)
# *    97: obj =   1.105107324e+01 inf =   1.724e-15 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    97: mip =     not found yet <=              +inf        (1; 0)
# +   179: >>>>>   6.000000000e+00 <=   6.000000000e+00   0.0% (8; 3)
# +   179: mip =   6.000000000e+00 <=     tree is empty   0.0% (0; 21)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.4 Mb (418655 bytes)
# Writing MIP solution to '/tmp/tmprid4e1yv.glpk.raw'...
# 321 lines were written
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpl9mkywiw.glpk.raw --wglp /tmp/tmp5x3zy8ug.glpk.glp --cpxlp
#  /tmp/tmp2efeyo8s.pyomo.lp
# Reading problem data from '/tmp/tmp2efeyo8s.pyomo.lp'...
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# 2514 lines were read
# Writing problem data to '/tmp/tmp5x3zy8ug.glpk.glp'...
# 2285 lines were written
# GLPK Integer Optimizer, v4.65
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# Preprocessing...
# 2 constraint coefficient(s) were reduced
# 123 rows, 56 columns, 681 non-zeros
# 56 integer variables, 9 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.500e+01  ratio =  1.500e+01
# GM: min|aij| =  2.627e-01  max|aij| =  3.807e+00  ratio =  1.449e+01
# EQ: min|aij| =  9.603e-02  max|aij| =  1.000e+00  ratio =  1.041e+01
# 2N: min|aij| =  6.250e-02  max|aij| =  1.000e+00  ratio =  1.600e+01
# Constructing initial basis...
# Size of triangular part is 123
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 123 rows, 56 columns, 681 non-zeros
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (3)
# *    86: obj =   2.501082069e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    86: mip =     not found yet <=              +inf        (1; 0)
# Solution found by heuristic: 0
# +   167: mip =   0.000000000e+00 <=     tree is empty   0.0% (0; 9)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.4 Mb (386364 bytes)
# Writing MIP solution to '/tmp/tmpl9mkywiw.glpk.raw'...
# 321 lines were written
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmp4xkmvirs.glpk.raw --wglp /tmp/tmpiji728y1.glpk.glp --cpxlp
#  /tmp/tmpczkv83yl.pyomo.lp
# Reading problem data from '/tmp/tmpczkv83yl.pyomo.lp'...
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# 2514 lines were read
# Writing problem data to '/tmp/tmpiji728y1.glpk.glp'...
# 2285 lines were written
# GLPK Integer Optimizer, v4.65
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# Preprocessing...
# 2 constraint coefficient(s) were reduced
# 122 rows, 56 columns, 681 non-zeros
# 56 integer variables, 7 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.500e+01  ratio =  1.500e+01
# GM: min|aij| =  4.009e-01  max|aij| =  2.495e+00  ratio =  6.223e+00
# EQ: min|aij| =  1.667e-01  max|aij| =  1.000e+00  ratio =  5.999e+00
# 2N: min|aij| =  1.250e-01  max|aij| =  1.500e+00  ratio =  1.200e+01
# Constructing initial basis...
# Size of triangular part is 122
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 122 rows, 56 columns, 681 non-zeros
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (3)
# *    80: obj =   2.932072222e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    80: mip =     not found yet <=              +inf        (1; 0)
# +   151: >>>>>   0.000000000e+00 <=   1.000000000e+00        (7; 2)
# +   213: mip =   0.000000000e+00 <=     tree is empty   0.0% (0; 21)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.4 Mb (394798 bytes)
# Writing MIP solution to '/tmp/tmp4xkmvirs.glpk.raw'...
# 321 lines were written
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpmjarxara.glpk.raw --wglp /tmp/tmpyybfs5v6.glpk.glp --cpxlp
#  /tmp/tmp0w_2c2wd.pyomo.lp
# Reading problem data from '/tmp/tmp0w_2c2wd.pyomo.lp'...
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# 2514 lines were read
# Writing problem data to '/tmp/tmpyybfs5v6.glpk.glp'...
# 2285 lines were written
# GLPK Integer Optimizer, v4.65
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# Preprocessing...
# 2 constraint coefficient(s) were reduced
# 125 rows, 58 columns, 704 non-zeros
# 58 integer variables, 7 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.900e+01  ratio =  1.900e+01
# GM: min|aij| =  4.079e-01  max|aij| =  2.452e+00  ratio =  6.010e+00
# EQ: min|aij| =  1.701e-01  max|aij| =  1.000e+00  ratio =  5.878e+00
# 2N: min|aij| =  9.375e-02  max|aij| =  1.188e+00  ratio =  1.267e+01
# Constructing initial basis...
# Size of triangular part is 125
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 125 rows, 58 columns, 704 non-zeros
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (4)
# *    82: obj =   3.658833620e+00 inf =   3.239e-16 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    82: mip =     not found yet <=              +inf        (1; 0)
# +   438: >>>>>   0.000000000e+00 <=   1.000000000e+00        (23; 9)
# +   601: mip =   0.000000000e+00 <=     tree is empty   0.0% (0; 73)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.4 Mb (423222 bytes)
# Writing MIP solution to '/tmp/tmpmjarxara.glpk.raw'...
# 321 lines were written
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpmlkqbzaw.glpk.raw --wglp /tmp/tmp_ixdeyls.glpk.glp --cpxlp
#  /tmp/tmpc2zb6hjf.pyomo.lp
# Reading problem data from '/tmp/tmpc2zb6hjf.pyomo.lp'...
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# 2514 lines were read
# Writing problem data to '/tmp/tmp_ixdeyls.glpk.glp'...
# 2285 lines were written
# GLPK Integer Optimizer, v4.65
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# Preprocessing...
# 2 constraint coefficient(s) were reduced
# 129 rows, 60 columns, 728 non-zeros
# 60 integer variables, 7 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.700e+01  ratio =  1.700e+01
# GM: min|aij| =  4.310e-01  max|aij| =  2.320e+00  ratio =  5.382e+00
# EQ: min|aij| =  1.894e-01  max|aij| =  1.000e+00  ratio =  5.280e+00
# 2N: min|aij| =  1.250e-01  max|aij| =  1.062e+00  ratio =  8.500e+00
# Constructing initial basis...
# Size of triangular part is 129
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 129 rows, 60 columns, 728 non-zeros
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (5)
# *    90: obj =   5.162008860e+00 inf =   2.776e-17 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    90: mip =     not found yet <=              +inf        (1; 0)
# +   393: >>>>>   0.000000000e+00 <=   2.000000000e+00        (17; 10)
# Solution found by heuristic: 1
# +   739: mip =   1.000000000e+00 <=     tree is empty   0.0% (0; 119)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.4 Mb (449176 bytes)
# Writing MIP solution to '/tmp/tmpmlkqbzaw.glpk.raw'...
# 321 lines were written
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpsn7_08s9.glpk.raw --wglp /tmp/tmpsx5kxjy3.glpk.glp --cpxlp
#  /tmp/tmpd3kuqrc1.pyomo.lp
# Reading problem data from '/tmp/tmpd3kuqrc1.pyomo.lp'...
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# 2514 lines were read
# Writing problem data to '/tmp/tmpsx5kxjy3.glpk.glp'...
# 2285 lines were written
# GLPK Integer Optimizer, v4.65
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# Preprocessing...
# 2 constraint coefficient(s) were reduced
# 121 rows, 55 columns, 675 non-zeros
# 55 integer variables, 8 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.600e+01  ratio =  1.600e+01
# GM: min|aij| =  2.585e-01  max|aij| =  3.869e+00  ratio =  1.497e+01
# EQ: min|aij| =  9.449e-02  max|aij| =  1.000e+00  ratio =  1.058e+01
# 2N: min|aij| =  6.250e-02  max|aij| =  1.000e+00  ratio =  1.600e+01
# Constructing initial basis...
# Size of triangular part is 121
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 121 rows, 55 columns, 675 non-zeros
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (2)
# *    82: obj =   1.645705542e+00 inf =   2.220e-16 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    82: mip =     not found yet <=              +inf        (1; 0)
# +   113: >>>>>   0.000000000e+00 <=   0.000000000e+00   0.0% (6; 0)
# +   113: mip =   0.000000000e+00 <=     tree is empty   0.0% (0; 11)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.4 Mb (383597 bytes)
# Writing MIP solution to '/tmp/tmpsn7_08s9.glpk.raw'...
# 321 lines were written
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmp4e0x7q1c.glpk.raw --wglp /tmp/tmpy58aws50.glpk.glp --cpxlp
#  /tmp/tmpyry_x6_i.pyomo.lp
# Reading problem data from '/tmp/tmpyry_x6_i.pyomo.lp'...
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# 2514 lines were read
# Writing problem data to '/tmp/tmpy58aws50.glpk.glp'...
# 2285 lines were written
# GLPK Integer Optimizer, v4.65
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# Preprocessing...
# 128 rows, 62 columns, 760 non-zeros
# 62 integer variables, 5 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.600e+01  ratio =  1.600e+01
# GM: min|aij| =  3.886e-01  max|aij| =  2.574e+00  ratio =  6.624e+00
# EQ: min|aij| =  1.518e-01  max|aij| =  1.000e+00  ratio =  6.588e+00
# 2N: min|aij| =  1.250e-01  max|aij| =  1.125e+00  ratio =  9.000e+00
# Constructing initial basis...
# Size of triangular part is 128
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 128 rows, 62 columns, 760 non-zeros
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (6)
# *    95: obj =   9.621115790e+00 inf =   2.304e-15 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    95: mip =     not found yet <=              +inf        (1; 0)
# Solution found by heuristic: 5
# +   779: mip =   5.000000000e+00 <=     tree is empty   0.0% (0; 135)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.4 Mb (467222 bytes)
# Writing MIP solution to '/tmp/tmp4e0x7q1c.glpk.raw'...
# 321 lines were written
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpgl3fuzgi.glpk.raw --wglp /tmp/tmp8uol9v_q.glpk.glp --cpxlp
#  /tmp/tmpx6sawlq5.pyomo.lp
# Reading problem data from '/tmp/tmpx6sawlq5.pyomo.lp'...
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# 2514 lines were read
# Writing problem data to '/tmp/tmp8uol9v_q.glpk.glp'...
# 2285 lines were written
# GLPK Integer Optimizer, v4.65
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# Preprocessing...
# 2 constraint coefficient(s) were reduced
# 133 rows, 64 columns, 765 non-zeros
# 64 integer variables, 6 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  7.000e+00  ratio =  7.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 133
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 133 rows, 64 columns, 765 non-zeros
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (8)
# *    86: obj =   1.804406893e+01 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    86: mip =     not found yet <=              +inf        (1; 0)
# +   300: >>>>>   5.000000000e+00 <=   1.400000000e+01 180.0% (7; 5)
# Solution found by heuristic: 8
# +  2791: >>>>>   9.000000000e+00 <=   9.000000000e+00   0.0% (29; 183)
# +  2791: mip =   9.000000000e+00 <=     tree is empty   0.0% (0; 307)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.1 secs
# Memory used: 0.5 Mb (519640 bytes)
# Writing MIP solution to '/tmp/tmpgl3fuzgi.glpk.raw'...
# 321 lines were written
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpqfaajrss.glpk.raw --wglp /tmp/tmp7tbcljki.glpk.glp --cpxlp
#  /tmp/tmpy_5j34r8.pyomo.lp
# Reading problem data from '/tmp/tmpy_5j34r8.pyomo.lp'...
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# 2514 lines were read
# Writing problem data to '/tmp/tmp7tbcljki.glpk.glp'...
# 2285 lines were written
# GLPK Integer Optimizer, v4.65
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# Preprocessing...
# 131 rows, 63 columns, 768 non-zeros
# 63 integer variables, 5 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.400e+01  ratio =  1.400e+01
# GM: min|aij| =  4.448e-01  max|aij| =  2.248e+00  ratio =  5.054e+00
# EQ: min|aij| =  1.988e-01  max|aij| =  1.000e+00  ratio =  5.030e+00
# 2N: min|aij| =  1.250e-01  max|aij| =  1.750e+00  ratio =  1.400e+01
# Constructing initial basis...
# Size of triangular part is 131
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 131 rows, 63 columns, 768 non-zeros
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (7)
# *    98: obj =   1.145929882e+01 inf =   1.499e-15 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    98: mip =     not found yet <=              +inf        (1; 0)
# +   345: >>>>>   5.000000000e+00 <=   7.000000000e+00  40.0% (22; 7)
# +   821: >>>>>   6.000000000e+00 <=   7.000000000e+00  16.7% (23; 51)
# +  1158: mip =   6.000000000e+00 <=     tree is empty   0.0% (0; 165)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.4 Mb (455465 bytes)
# Writing MIP solution to '/tmp/tmpqfaajrss.glpk.raw'...
# 321 lines were written
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmp1kfx3csd.glpk.raw --wglp /tmp/tmpchofgoj6.glpk.glp --cpxlp
#  /tmp/tmpigunagsy.pyomo.lp
# Reading problem data from '/tmp/tmpigunagsy.pyomo.lp'...
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# 2514 lines were read
# Writing problem data to '/tmp/tmpchofgoj6.glpk.glp'...
# 2285 lines were written
# GLPK Integer Optimizer, v4.65
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# Preprocessing...
# 1 constraint coefficient(s) were reduced
# 124 rows, 58 columns, 709 non-zeros
# 58 integer variables, 6 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.600e+01  ratio =  1.600e+01
# GM: min|aij| =  2.585e-01  max|aij| =  3.869e+00  ratio =  1.497e+01
# EQ: min|aij| =  9.139e-02  max|aij| =  1.000e+00  ratio =  1.094e+01
# 2N: min|aij| =  6.250e-02  max|aij| =  1.000e+00  ratio =  1.600e+01
# Constructing initial basis...
# Size of triangular part is 124
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 124 rows, 58 columns, 709 non-zeros
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (4)
# *    82: obj =   3.612079729e+00 inf =   4.996e-16 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    82: mip =     not found yet <=              +inf        (1; 0)
# Solution found by heuristic: 0
# +   425: mip =   0.000000000e+00 <=     tree is empty   0.0% (0; 87)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.4 Mb (429394 bytes)
# Writing MIP solution to '/tmp/tmp1kfx3csd.glpk.raw'...
# 321 lines were written
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmplndbl119.glpk.raw --wglp /tmp/tmpxabs42sk.glpk.glp --cpxlp
#  /tmp/tmpf2cr0ui5.pyomo.lp
# Reading problem data from '/tmp/tmpf2cr0ui5.pyomo.lp'...
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# 2514 lines were read
# Writing problem data to '/tmp/tmpxabs42sk.glpk.glp'...
# 2285 lines were written
# GLPK Integer Optimizer, v4.65
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# Preprocessing...
# 1 constraint coefficient(s) were reduced
# 131 rows, 62 columns, 781 non-zeros
# 62 integer variables, 5 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.900e+01  ratio =  1.900e+01
# GM: min|aij| =  2.325e-01  max|aij| =  4.300e+00  ratio =  1.849e+01
# EQ: min|aij| =  8.578e-02  max|aij| =  1.000e+00  ratio =  1.166e+01
# 2N: min|aij| =  1.250e-01  max|aij| =  1.500e+00  ratio =  1.200e+01
# Constructing initial basis...
# Size of triangular part is 131
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 131 rows, 62 columns, 781 non-zeros
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (5)
# *    94: obj =   4.723150395e+00 inf =   2.281e-15 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    94: mip =     not found yet <=              +inf        (1; 0)
# +   276: >>>>>   0.000000000e+00 <=   2.000000000e+00        (13; 3)
# +   320: >>>>>   1.000000000e+00 <=   2.000000000e+00 100.0% (13; 6)
# +  2032: mip =   1.000000000e+00 <=     tree is empty   0.0% (0; 269)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.1 secs
# Memory used: 0.4 Mb (422546 bytes)
# Writing MIP solution to '/tmp/tmplndbl119.glpk.raw'...
# 321 lines were written
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpnv0ka9ku.glpk.raw --wglp /tmp/tmpqefydtf0.glpk.glp --cpxlp
#  /tmp/tmp9oa7yqbn.pyomo.lp
# Reading problem data from '/tmp/tmp9oa7yqbn.pyomo.lp'...
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# 2514 lines were read
# Writing problem data to '/tmp/tmpqefydtf0.glpk.glp'...
# 2285 lines were written
# GLPK Integer Optimizer, v4.65
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# Preprocessing...
# 1 constraint coefficient(s) were reduced
# 134 rows, 63 columns, 782 non-zeros
# 63 integer variables, 6 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.300e+01  ratio =  1.300e+01
# GM: min|aij| =  2.830e-01  max|aij| =  3.534e+00  ratio =  1.249e+01
# EQ: min|aij| =  1.132e-01  max|aij| =  1.000e+00  ratio =  8.832e+00
# 2N: min|aij| =  6.250e-02  max|aij| =  1.500e+00  ratio =  2.400e+01
# Constructing initial basis...
# Size of triangular part is 134
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 134 rows, 63 columns, 782 non-zeros
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (6)
# *   101: obj =   8.479104605e+00 inf =   6.141e-16 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +   101: mip =     not found yet <=              +inf        (1; 0)
# +   538: >>>>>   2.000000000e+00 <=   4.000000000e+00 100.0% (31; 11)
# Solution found by heuristic: 3
# +   846: mip =   3.000000000e+00 <=     tree is empty   0.0% (0; 125)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.1 secs
# Memory used: 0.5 Mb (514489 bytes)
# Writing MIP solution to '/tmp/tmpnv0ka9ku.glpk.raw'...
# 321 lines were written
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpedw45xy3.glpk.raw --wglp /tmp/tmpppe_2_pq.glpk.glp --cpxlp
#  /tmp/tmpq8mcl055.pyomo.lp
# Reading problem data from '/tmp/tmpq8mcl055.pyomo.lp'...
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# 2514 lines were read
# Writing problem data to '/tmp/tmpppe_2_pq.glpk.glp'...
# 2285 lines were written
# GLPK Integer Optimizer, v4.65
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# Preprocessing...
# 1 constraint coefficient(s) were reduced
# 132 rows, 62 columns, 764 non-zeros
# 62 integer variables, 6 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.600e+01  ratio =  1.600e+01
# GM: min|aij| =  4.248e-01  max|aij| =  2.354e+00  ratio =  5.540e+00
# EQ: min|aij| =  1.860e-01  max|aij| =  1.000e+00  ratio =  5.377e+00
# 2N: min|aij| =  1.250e-01  max|aij| =  1.500e+00  ratio =  1.200e+01
# Constructing initial basis...
# Size of triangular part is 132
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 132 rows, 62 columns, 764 non-zeros
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (6)
# *    89: obj =   8.983479653e+00 inf =   2.820e-14 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    89: mip =     not found yet <=              +inf        (1; 0)
# +  1589: >>>>>   1.000000000e+00 <=   3.000000000e+00 200.0% (106; 48)
# +  1616: >>>>>   3.000000000e+00 <=   3.000000000e+00   0.0% (99; 57)
# +  1616: mip =   3.000000000e+00 <=     tree is empty   0.0% (0; 309)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.1 secs
# Memory used: 0.5 Mb (561728 bytes)
# Writing MIP solution to '/tmp/tmpedw45xy3.glpk.raw'...
# 321 lines were written
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpn87oexo4.glpk.raw --wglp /tmp/tmp3jwn7g75.glpk.glp --cpxlp
#  /tmp/tmptmc0qm_q.pyomo.lp
# Reading problem data from '/tmp/tmptmc0qm_q.pyomo.lp'...
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# 2514 lines were read
# Writing problem data to '/tmp/tmp3jwn7g75.glpk.glp'...
# 2285 lines were written
# GLPK Integer Optimizer, v4.65
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# Preprocessing...
# 1 constraint coefficient(s) were reduced
# 132 rows, 62 columns, 764 non-zeros
# 62 integer variables, 6 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.700e+01  ratio =  1.700e+01
# GM: min|aij| =  4.284e-01  max|aij| =  2.334e+00  ratio =  5.448e+00
# EQ: min|aij| =  1.899e-01  max|aij| =  1.000e+00  ratio =  5.266e+00
# 2N: min|aij| =  1.250e-01  max|aij| =  1.500e+00  ratio =  1.200e+01
# Constructing initial basis...
# Size of triangular part is 132
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 132 rows, 62 columns, 764 non-zeros
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (6)
# *    90: obj =   9.532886477e+00 inf =   4.806e-15 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    90: mip =     not found yet <=              +inf        (1; 0)
# +   660: >>>>>   3.000000000e+00 <=   5.000000000e+00  66.7% (34; 11)
# +  1017: >>>>>   4.000000000e+00 <=   4.000000000e+00   0.0% (16; 74)
# +  1017: mip =   4.000000000e+00 <=     tree is empty   0.0% (0; 129)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.4 Mb (455554 bytes)
# Writing MIP solution to '/tmp/tmpn87oexo4.glpk.raw'...
# 321 lines were written
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpum0y5f5r.glpk.raw --wglp /tmp/tmptxg1lnc6.glpk.glp --cpxlp
#  /tmp/tmpqgq4pm_n.pyomo.lp
# Reading problem data from '/tmp/tmpqgq4pm_n.pyomo.lp'...
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# 2514 lines were read
# Writing problem data to '/tmp/tmptxg1lnc6.glpk.glp'...
# 2285 lines were written
# GLPK Integer Optimizer, v4.65
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# Preprocessing...
# 1 constraint coefficient(s) were reduced
# 142 rows, 68 columns, 863 non-zeros
# 68 integer variables, 6 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.700e+01  ratio =  1.700e+01
# GM: min|aij| =  4.201e-01  max|aij| =  2.380e+00  ratio =  5.665e+00
# EQ: min|aij| =  1.789e-01  max|aij| =  1.000e+00  ratio =  5.589e+00
# 2N: min|aij| =  1.250e-01  max|aij| =  1.250e+00  ratio =  1.000e+01
# Constructing initial basis...
# Size of triangular part is 142
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 142 rows, 68 columns, 863 non-zeros
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (8)
# *   105: obj =   1.529318353e+01 inf =   3.518e-15 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +   105: mip =     not found yet <=              +inf        (1; 0)
# Solution found by heuristic: 5
# +   304: >>>>>   9.000000000e+00 <=   1.000000000e+01  11.1% (15; 7)
# +   677: mip =   9.000000000e+00 <=     tree is empty   0.0% (0; 81)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.4 Mb (451834 bytes)
# Writing MIP solution to '/tmp/tmpum0y5f5r.glpk.raw'...
# 321 lines were written
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpw61s98a7.glpk.raw --wglp /tmp/tmpu6euoofy.glpk.glp --cpxlp
#  /tmp/tmpcc5y81of.pyomo.lp
# Reading problem data from '/tmp/tmpcc5y81of.pyomo.lp'...
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# 2514 lines were read
# Writing problem data to '/tmp/tmpu6euoofy.glpk.glp'...
# 2285 lines were written
# GLPK Integer Optimizer, v4.65
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# Preprocessing...
# 1 constraint coefficient(s) were reduced
# 135 rows, 65 columns, 811 non-zeros
# 65 integer variables, 6 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.600e+01  ratio =  1.600e+01
# GM: min|aij| =  3.950e-01  max|aij| =  2.531e+00  ratio =  6.408e+00
# EQ: min|aij| =  1.564e-01  max|aij| =  1.000e+00  ratio =  6.395e+00
# 2N: min|aij| =  1.250e-01  max|aij| =  1.375e+00  ratio =  1.100e+01
# Constructing initial basis...
# Size of triangular part is 135
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 135 rows, 65 columns, 811 non-zeros
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (7)
# *    97: obj =   1.060964057e+01 inf =   1.800e-15 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    97: mip =     not found yet <=              +inf        (1; 0)
# +   264: >>>>>   5.000000000e+00 <=   5.000000000e+00   0.0% (8; 11)
# +   264: mip =   5.000000000e+00 <=     tree is empty   0.0% (0; 35)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.4 Mb (418585 bytes)
# Writing MIP solution to '/tmp/tmpw61s98a7.glpk.raw'...
# 321 lines were written
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpdfpno45i.glpk.raw --wglp /tmp/tmpqxqxd885.glpk.glp --cpxlp
#  /tmp/tmphtouav8_.pyomo.lp
# Reading problem data from '/tmp/tmphtouav8_.pyomo.lp'...
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# 2514 lines were read
# Writing problem data to '/tmp/tmpqxqxd885.glpk.glp'...
# 2285 lines were written
# GLPK Integer Optimizer, v4.65
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# Preprocessing...
# 2 constraint coefficient(s) were reduced
# 124 rows, 58 columns, 693 non-zeros
# 58 integer variables, 7 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.200e+01  ratio =  1.200e+01
# GM: min|aij| =  4.367e-01  max|aij| =  2.290e+00  ratio =  5.243e+00
# EQ: min|aij| =  1.920e-01  max|aij| =  1.000e+00  ratio =  5.207e+00
# 2N: min|aij| =  1.250e-01  max|aij| =  1.500e+00  ratio =  1.200e+01
# Constructing initial basis...
# Size of triangular part is 124
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 124 rows, 58 columns, 693 non-zeros
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (5)
# *    84: obj =   6.794239901e+00 inf =   9.422e-17 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    84: mip =     not found yet <=              +inf        (1; 0)
# +   392: >>>>>   1.000000000e+00 <=   3.000000000e+00 200.0% (15; 8)
# +   674: >>>>>   2.000000000e+00 <=   2.000000000e+00   0.0% (20; 26)
# +   674: mip =   2.000000000e+00 <=     tree is empty   0.0% (0; 85)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.4 Mb (421854 bytes)
# Writing MIP solution to '/tmp/tmpdfpno45i.glpk.raw'...
# 321 lines were written
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpny3f9erf.glpk.raw --wglp /tmp/tmpk0tf5i0p.glpk.glp --cpxlp
#  /tmp/tmpihf65bzs.pyomo.lp
# Reading problem data from '/tmp/tmpihf65bzs.pyomo.lp'...
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# 2514 lines were read
# Writing problem data to '/tmp/tmpk0tf5i0p.glpk.glp'...
# 2285 lines were written
# GLPK Integer Optimizer, v4.65
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# Preprocessing...
# 1 constraint coefficient(s) were reduced
# 126 rows, 59 columns, 726 non-zeros
# 59 integer variables, 6 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.700e+01  ratio =  1.700e+01
# GM: min|aij| =  3.945e-01  max|aij| =  2.535e+00  ratio =  6.425e+00
# EQ: min|aij| =  1.566e-01  max|aij| =  1.000e+00  ratio =  6.385e+00
# 2N: min|aij| =  9.375e-02  max|aij| =  1.500e+00  ratio =  1.600e+01
# Constructing initial basis...
# Size of triangular part is 126
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 126 rows, 59 columns, 726 non-zeros
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (4)
# *    90: obj =   3.932956982e+00 inf =   1.665e-16 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    90: mip =     not found yet <=              +inf        (1; 0)
# Solution found by heuristic: 1
# +   236: mip =   1.000000000e+00 <=     tree is empty   0.0% (0; 23)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.4 Mb (456295 bytes)
# Writing MIP solution to '/tmp/tmpny3f9erf.glpk.raw'...
# 321 lines were written
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpjb0o5uqs.glpk.raw --wglp /tmp/tmpvvcpr_ku.glpk.glp --cpxlp
#  /tmp/tmp0lkcp_la.pyomo.lp
# Reading problem data from '/tmp/tmp0lkcp_la.pyomo.lp'...
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# 2514 lines were read
# Writing problem data to '/tmp/tmpvvcpr_ku.glpk.glp'...
# 2285 lines were written
# GLPK Integer Optimizer, v4.65
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# Preprocessing...
# 1 constraint coefficient(s) were reduced
# 137 rows, 66 columns, 813 non-zeros
# 66 integer variables, 5 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  9.000e+00  ratio =  9.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 137
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 137 rows, 66 columns, 813 non-zeros
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (8)
# *    97: obj =   2.001362603e+01 inf =   2.961e-15 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    97: mip =     not found yet <=              +inf        (1; 0)
# +  1388: >>>>>   1.200000000e+01 <=   1.300000000e+01   8.3% (47; 35)
# +  2396: mip =   1.200000000e+01 <=     tree is empty   0.0% (0; 249)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.1 secs
# Memory used: 0.5 Mb (488122 bytes)
# Writing MIP solution to '/tmp/tmpjb0o5uqs.glpk.raw'...
# 321 lines were written
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpz4w64vox.glpk.raw --wglp /tmp/tmp83utky94.glpk.glp --cpxlp
#  /tmp/tmpw6ig9sw2.pyomo.lp
# Reading problem data from '/tmp/tmpw6ig9sw2.pyomo.lp'...
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# 2514 lines were read
# Writing problem data to '/tmp/tmp83utky94.glpk.glp'...
# 2285 lines were written
# GLPK Integer Optimizer, v4.65
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# Preprocessing...
# 128 rows, 60 columns, 750 non-zeros
# 60 integer variables, 5 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.000e+01  ratio =  2.000e+01
# GM: min|aij| =  2.329e-01  max|aij| =  4.294e+00  ratio =  1.844e+01
# EQ: min|aij| =  8.110e-02  max|aij| =  1.000e+00  ratio =  1.233e+01
# 2N: min|aij| =  6.250e-02  max|aij| =  1.250e+00  ratio =  2.000e+01
# Constructing initial basis...
# Size of triangular part is 128
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 128 rows, 60 columns, 750 non-zeros
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (4)
# *    90: obj =   3.403256986e+00 inf =   1.332e-15 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    90: mip =     not found yet <=              +inf        (1; 0)
# +   147: >>>>>   0.000000000e+00 <=   1.000000000e+00        (10; 1)
# +   159: >>>>>   1.000000000e+00 <=   1.000000000e+00   0.0% (8; 7)
# +   159: mip =   1.000000000e+00 <=     tree is empty   0.0% (0; 25)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.4 Mb (410376 bytes)
# Writing MIP solution to '/tmp/tmpz4w64vox.glpk.raw'...
# 321 lines were written
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpg6qcgye0.glpk.raw --wglp /tmp/tmpnilftd5k.glpk.glp --cpxlp
#  /tmp/tmp711cuej_.pyomo.lp
# Reading problem data from '/tmp/tmp711cuej_.pyomo.lp'...
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# 2514 lines were read
# Writing problem data to '/tmp/tmpnilftd5k.glpk.glp'...
# 2285 lines were written
# GLPK Integer Optimizer, v4.65
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# Preprocessing...
# 1 constraint coefficient(s) were reduced
# 125 rows, 58 columns, 709 non-zeros
# 58 integer variables, 8 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.900e+01  ratio =  1.900e+01
# GM: min|aij| =  4.043e-01  max|aij| =  2.473e+00  ratio =  6.117e+00
# EQ: min|aij| =  1.696e-01  max|aij| =  1.000e+00  ratio =  5.896e+00
# 2N: min|aij| =  1.250e-01  max|aij| =  1.500e+00  ratio =  1.200e+01
# Constructing initial basis...
# Size of triangular part is 125
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 125 rows, 58 columns, 709 non-zeros
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (4)
# *    85: obj =   4.566587452e+00 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    85: mip =     not found yet <=              +inf        (1; 0)
# Solution found by heuristic: 0
# +   473: >>>>>   1.000000000e+00 <=   2.000000000e+00 100.0% (12; 24)
# +   484: mip =   1.000000000e+00 <=     tree is empty   0.0% (0; 57)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.4 Mb (413194 bytes)
# Writing MIP solution to '/tmp/tmpg6qcgye0.glpk.raw'...
# 321 lines were written
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmp_hkenq6s.glpk.raw --wglp /tmp/tmp47orhn2l.glpk.glp --cpxlp
#  /tmp/tmpjcsa5hu2.pyomo.lp
# Reading problem data from '/tmp/tmpjcsa5hu2.pyomo.lp'...
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# 2514 lines were read
# Writing problem data to '/tmp/tmp47orhn2l.glpk.glp'...
# 2285 lines were written
# GLPK Integer Optimizer, v4.65
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# Preprocessing...
# 2 constraint coefficient(s) were reduced
# 127 rows, 60 columns, 716 non-zeros
# 60 integer variables, 7 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  9.000e+00  ratio =  9.000e+00
# Problem data seem to be well scaled
# Constructing initial basis...
# Size of triangular part is 127
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 127 rows, 60 columns, 716 non-zeros
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (6)
# *    82: obj =   1.117373431e+01 inf =   5.551e-17 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    82: mip =     not found yet <=              +inf        (1; 0)
# Solution found by heuristic: 2
# Solution found by heuristic: 5
# +  1027: mip =   5.000000000e+00 <=     tree is empty   0.0% (0; 105)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.4 Mb (442310 bytes)
# Writing MIP solution to '/tmp/tmp_hkenq6s.glpk.raw'...
# 321 lines were written
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmp4ksrdpwd.glpk.raw --wglp /tmp/tmpn8_ehqq1.glpk.glp --cpxlp
#  /tmp/tmpgjysdvr8.pyomo.lp
# Reading problem data from '/tmp/tmpgjysdvr8.pyomo.lp'...
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# 2514 lines were read
# Writing problem data to '/tmp/tmpn8_ehqq1.glpk.glp'...
# 2285 lines were written
# GLPK Integer Optimizer, v4.65
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# Preprocessing...
# 1 constraint coefficient(s) were reduced
# 135 rows, 64 columns, 806 non-zeros
# 64 integer variables, 6 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.900e+01  ratio =  1.900e+01
# GM: min|aij| =  3.888e-01  max|aij| =  2.572e+00  ratio =  6.615e+00
# EQ: min|aij| =  1.540e-01  max|aij| =  1.000e+00  ratio =  6.495e+00
# 2N: min|aij| =  9.375e-02  max|aij| =  1.188e+00  ratio =  1.267e+01
# Constructing initial basis...
# Size of triangular part is 135
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 135 rows, 64 columns, 806 non-zeros
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (6)
# *   105: obj =   6.523224959e+00 inf =   5.109e-15 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +   105: mip =     not found yet <=              +inf        (1; 0)
# +   286: >>>>>   2.000000000e+00 <=   3.000000000e+00  50.0% (17; 6)
# +   332: >>>>>   3.000000000e+00 <=   3.000000000e+00   0.0% (5; 29)
# +   332: mip =   3.000000000e+00 <=     tree is empty   0.0% (0; 49)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.4 Mb (434096 bytes)
# Writing MIP solution to '/tmp/tmp4ksrdpwd.glpk.raw'...
# 321 lines were written
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmp2vjyyfs9.glpk.raw --wglp /tmp/tmpkjh4sa2d.glpk.glp --cpxlp
#  /tmp/tmpa1gjh723.pyomo.lp
# Reading problem data from '/tmp/tmpa1gjh723.pyomo.lp'...
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# 2514 lines were read
# Writing problem data to '/tmp/tmpkjh4sa2d.glpk.glp'...
# 2285 lines were written
# GLPK Integer Optimizer, v4.65
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# Preprocessing...
# 1 constraint coefficient(s) were reduced
# 130 rows, 60 columns, 752 non-zeros
# 60 integer variables, 6 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  2.000e+01  ratio =  2.000e+01
# GM: min|aij| =  3.839e-01  max|aij| =  2.605e+00  ratio =  6.786e+00
# EQ: min|aij| =  1.475e-01  max|aij| =  1.000e+00  ratio =  6.778e+00
# 2N: min|aij| =  9.375e-02  max|aij| =  1.250e+00  ratio =  1.333e+01
# Constructing initial basis...
# Size of triangular part is 130
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 130 rows, 60 columns, 752 non-zeros
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (4)
# *    92: obj =   3.352895915e+00 inf =   6.211e-15 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    92: mip =     not found yet <=              +inf        (1; 0)
# +   204: >>>>>   0.000000000e+00 <=   1.000000000e+00        (13; 1)
# +   261: mip =   0.000000000e+00 <=     tree is empty   0.0% (0; 31)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.5 Mb (474422 bytes)
# Writing MIP solution to '/tmp/tmp2vjyyfs9.glpk.raw'...
# 321 lines were written
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpz85jb6mm.glpk.raw --wglp /tmp/tmpubyeg7t9.glpk.glp --cpxlp
#  /tmp/tmps0g_38_2.pyomo.lp
# Reading problem data from '/tmp/tmps0g_38_2.pyomo.lp'...
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# 2514 lines were read
# Writing problem data to '/tmp/tmpubyeg7t9.glpk.glp'...
# 2285 lines were written
# GLPK Integer Optimizer, v4.65
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# Preprocessing...
# 1 constraint coefficient(s) were reduced
# 123 rows, 57 columns, 694 non-zeros
# 57 integer variables, 6 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.900e+01  ratio =  1.900e+01
# GM: min|aij| =  4.122e-01  max|aij| =  2.426e+00  ratio =  5.885e+00
# EQ: min|aij| =  1.705e-01  max|aij| =  1.000e+00  ratio =  5.864e+00
# 2N: min|aij| =  1.250e-01  max|aij| =  1.500e+00  ratio =  1.200e+01
# Constructing initial basis...
# Size of triangular part is 123
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 123 rows, 57 columns, 694 non-zeros
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (4)
# *    81: obj =   3.697129272e+00 inf =   3.519e-16 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    81: mip =     not found yet <=              +inf        (1; 0)
# +   297: >>>>>   0.000000000e+00 <=   1.000000000e+00        (16; 5)
# +  1305: mip =   0.000000000e+00 <=     tree is empty   0.0% (0; 217)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.1 secs
# Memory used: 0.4 Mb (419957 bytes)
# Writing MIP solution to '/tmp/tmpz85jb6mm.glpk.raw'...
# 321 lines were written
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpyxnl4sw7.glpk.raw --wglp /tmp/tmprnpdy9fy.glpk.glp --cpxlp
#  /tmp/tmpgzumrjot.pyomo.lp
# Reading problem data from '/tmp/tmpgzumrjot.pyomo.lp'...
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# 2514 lines were read
# Writing problem data to '/tmp/tmprnpdy9fy.glpk.glp'...
# 2285 lines were written
# GLPK Integer Optimizer, v4.65
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# Preprocessing...
# 1 constraint coefficient(s) were reduced
# 133 rows, 63 columns, 763 non-zeros
# 63 integer variables, 8 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.100e+01  ratio =  1.100e+01
# GM: min|aij| =  4.437e-01  max|aij| =  2.254e+00  ratio =  5.079e+00
# EQ: min|aij| =  1.999e-01  max|aij| =  1.000e+00  ratio =  5.003e+00
# 2N: min|aij| =  2.500e-01  max|aij| =  1.500e+00  ratio =  6.000e+00
# Constructing initial basis...
# Size of triangular part is 133
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 133 rows, 63 columns, 763 non-zeros
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (7)
# *   109: obj =   1.321416665e+01 inf =   0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +   109: mip =     not found yet <=              +inf        (1; 0)
# +   389: >>>>>   3.000000000e+00 <=   8.000000000e+00 166.7% (8; 10)
# +  1352: >>>>>   6.000000000e+00 <=   7.000000000e+00  16.7% (44; 39)
# +  1924: mip =   6.000000000e+00 <=     tree is empty   0.0% (0; 253)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.1 secs
# Memory used: 0.5 Mb (490271 bytes)
# Writing MIP solution to '/tmp/tmpyxnl4sw7.glpk.raw'...
# 321 lines were written
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpo8vmt7ii.glpk.raw --wglp /tmp/tmp1ssknabi.glpk.glp --cpxlp
#  /tmp/tmpfgbw7tic.pyomo.lp
# Reading problem data from '/tmp/tmpfgbw7tic.pyomo.lp'...
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# 2514 lines were read
# Writing problem data to '/tmp/tmp1ssknabi.glpk.glp'...
# 2285 lines were written
# GLPK Integer Optimizer, v4.65
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# Preprocessing...
# 1 constraint coefficient(s) were reduced
# 136 rows, 65 columns, 807 non-zeros
# 65 integer variables, 5 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.200e+01  ratio =  1.200e+01
# GM: min|aij| =  4.370e-01  max|aij| =  2.288e+00  ratio =  5.236e+00
# EQ: min|aij| =  1.916e-01  max|aij| =  1.000e+00  ratio =  5.219e+00
# 2N: min|aij| =  1.250e-01  max|aij| =  1.500e+00  ratio =  1.200e+01
# Constructing initial basis...
# Size of triangular part is 136
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 136 rows, 65 columns, 807 non-zeros
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (7)
# *   106: obj =   1.270630740e+01 inf =   1.048e-15 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +   106: mip =     not found yet <=              +inf        (1; 0)
# +   595: >>>>>   6.000000000e+00 <=   8.000000000e+00  33.3% (23; 18)
# +   957: >>>>>   7.000000000e+00 <=   7.000000000e+00   0.0% (13; 63)
# +   957: mip =   7.000000000e+00 <=     tree is empty   0.0% (0; 115)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.4 Mb (445679 bytes)
# Writing MIP solution to '/tmp/tmpo8vmt7ii.glpk.raw'...
# 321 lines were written
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmp4wns_n1m.glpk.raw --wglp /tmp/tmphywn70nz.glpk.glp --cpxlp
#  /tmp/tmpz0twbo4h.pyomo.lp
# Reading problem data from '/tmp/tmpz0twbo4h.pyomo.lp'...
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# 2514 lines were read
# Writing problem data to '/tmp/tmphywn70nz.glpk.glp'...
# 2285 lines were written
# GLPK Integer Optimizer, v4.65
# 215 rows, 97 columns, 1638 non-zeros
# 96 integer variables, none of which are binary
# Preprocessing...
# 2 constraint coefficient(s) were reduced
# 125 rows, 59 columns, 710 non-zeros
# 59 integer variables, 7 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.500e+01  ratio =  1.500e+01
# GM: min|aij| =  4.027e-01  max|aij| =  2.483e+00  ratio =  6.166e+00
# EQ: min|aij| =  1.624e-01  max|aij| =  1.000e+00  ratio =  6.157e+00
# 2N: min|aij| =  1.250e-01  max|aij| =  1.000e+00  ratio =  8.000e+00
# Constructing initial basis...
# Size of triangular part is 125
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 125 rows, 59 columns, 710 non-zeros
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (5)
# *    88: obj =   5.260011874e+00 inf =   1.388e-17 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +    88: mip =     not found yet <=              +inf        (1; 0)
# +   699: >>>>>   0.000000000e+00 <=   1.000000000e+00        (27; 25)
# +   709: >>>>>   1.000000000e+00 <=   1.000000000e+00   0.0% (23; 36)
# +   709: mip =   1.000000000e+00 <=     tree is empty   0.0% (0; 105)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.4 Mb (434391 bytes)
# Writing MIP solution to '/tmp/tmp4wns_n1m.glpk.raw'...
# 321 lines were written

# %%
# quality_level

# %%
sum(quality_level)
# Out:
# 1589.0

# %%
## PART 2 ##

# %%
values = []
for i, bp in enumerate(blueprints[:3]):
    values.append(solve_for_blueprint(bp, 32))
# Out:
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpskitpi0e.glpk.raw --wglp /tmp/tmpszvy9r1g.glpk.glp --cpxlp
#  /tmp/tmpy_6kk2s0.pyomo.lp
# Reading problem data from '/tmp/tmpy_6kk2s0.pyomo.lp'...
# 287 rows, 129 columns, 2702 non-zeros
# 128 integer variables, none of which are binary
# 3866 lines were read
# Writing problem data to '/tmp/tmpszvy9r1g.glpk.glp'...
# 3565 lines were written
# GLPK Integer Optimizer, v4.65
# 287 rows, 129 columns, 2702 non-zeros
# 128 integer variables, none of which are binary
# Preprocessing...
# 1 constraint coefficient(s) were reduced
# 194 rows, 93 columns, 1434 non-zeros
# 93 integer variables, 7 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.900e+01  ratio =  1.900e+01
# GM: min|aij| =  3.755e-01  max|aij| =  2.663e+00  ratio =  7.094e+00
# EQ: min|aij| =  1.419e-01  max|aij| =  1.000e+00  ratio =  7.047e+00
# 2N: min|aij| =  1.250e-01  max|aij| =  1.500e+00  ratio =  1.200e+01
# Constructing initial basis...
# Size of triangular part is 194
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 194 rows, 93 columns, 1434 non-zeros
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (13)
# *   148: obj =   3.537107310e+01 inf =   2.328e-15 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +   148: mip =     not found yet <=              +inf        (1; 0)
# +   824: >>>>>   2.200000000e+01 <=   2.300000000e+01   4.5% (47; 16)
# +   895: mip =   2.200000000e+01 <=     tree is empty   0.0% (0; 135)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.7 Mb (771827 bytes)
# Writing MIP solution to '/tmp/tmpskitpi0e.glpk.raw'...
# 425 lines were written
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmp1lavcxls.glpk.raw --wglp /tmp/tmpn_zx8p44.glpk.glp --cpxlp
#  /tmp/tmpsr8gsd6x.pyomo.lp
# Reading problem data from '/tmp/tmpsr8gsd6x.pyomo.lp'...
# 287 rows, 129 columns, 2702 non-zeros
# 128 integer variables, none of which are binary
# 3866 lines were read
# Writing problem data to '/tmp/tmpn_zx8p44.glpk.glp'...
# 3565 lines were written
# GLPK Integer Optimizer, v4.65
# 287 rows, 129 columns, 2702 non-zeros
# 128 integer variables, none of which are binary
# Preprocessing...
# 1 constraint coefficient(s) were reduced
# 194 rows, 93 columns, 1434 non-zeros
# 93 integer variables, 7 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.900e+01  ratio =  1.900e+01
# GM: min|aij| =  3.940e-01  max|aij| =  2.538e+00  ratio =  6.440e+00
# EQ: min|aij| =  1.559e-01  max|aij| =  1.000e+00  ratio =  6.413e+00
# 2N: min|aij| =  1.250e-01  max|aij| =  1.500e+00  ratio =  1.200e+01
# Constructing initial basis...
# Size of triangular part is 194
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 194 rows, 93 columns, 1434 non-zeros
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (13)
# *   141: obj =   4.617215659e+01 inf =   2.014e-14 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +   141: mip =     not found yet <=              +inf        (1; 0)
# +   623: >>>>>   2.900000000e+01 <=   3.200000000e+01  10.3% (17; 19)
# + 17261: mip =   2.900000000e+01 <=     tree is empty   0.0% (0; 1787)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.7 secs
# Memory used: 1.4 Mb (1481015 bytes)
# Writing MIP solution to '/tmp/tmp1lavcxls.glpk.raw'...
# 425 lines were written
# GLPSOL: GLPK LP/MIP Solver, v4.65
# Parameter(s) specified in the command line:
#  --write /tmp/tmpnz3wr1cu.glpk.raw --wglp /tmp/tmp5_b0a2uh.glpk.glp --cpxlp
#  /tmp/tmpqxcm0juw.pyomo.lp
# Reading problem data from '/tmp/tmpqxcm0juw.pyomo.lp'...
# 287 rows, 129 columns, 2702 non-zeros
# 128 integer variables, none of which are binary
# 3866 lines were read
# Writing problem data to '/tmp/tmp5_b0a2uh.glpk.glp'...
# 3565 lines were written
# GLPK Integer Optimizer, v4.65
# 287 rows, 129 columns, 2702 non-zeros
# 128 integer variables, none of which are binary
# Preprocessing...
# 1 constraint coefficient(s) were reduced
# 200 rows, 97 columns, 1504 non-zeros
# 97 integer variables, 6 of which are binary
# Scaling...
#  A: min|aij| =  1.000e+00  max|aij| =  1.700e+01  ratio =  1.700e+01
# GM: min|aij| =  4.181e-01  max|aij| =  2.392e+00  ratio =  5.720e+00
# EQ: min|aij| =  1.781e-01  max|aij| =  1.000e+00  ratio =  5.616e+00
# 2N: min|aij| =  1.250e-01  max|aij| =  1.500e+00  ratio =  1.200e+01
# Constructing initial basis...
# Size of triangular part is 200
# Solving LP relaxation...
# GLPK Simplex Optimizer, v4.65
# 200 rows, 97 columns, 1504 non-zeros
# *     0: obj =  -0.000000000e+00 inf =   0.000e+00 (15)
# *   148: obj =   5.674279836e+01 inf =   2.514e-15 (0)
# OPTIMAL LP SOLUTION FOUND
# Integer optimization begins...
# Long-step dual simplex will be used
# +   148: mip =     not found yet <=              +inf        (1; 0)
# +  1092: >>>>>   3.300000000e+01 <=   4.700000000e+01  42.4% (88; 18)
# +  1172: >>>>>   4.600000000e+01 <=   4.600000000e+01   0.0% (75; 47)
# +  1172: mip =   4.600000000e+01 <=     tree is empty   0.0% (0; 221)
# INTEGER OPTIMAL SOLUTION FOUND
# Time used:   0.1 secs
# Memory used: 0.8 Mb (842267 bytes)
# Writing MIP solution to '/tmp/tmpnz3wr1cu.glpk.raw'...
# 425 lines were written

# %%
values
# Out:
# [22.0, 29.0, 46.0]

# %%
import operator
from functools import reduce
reduce(operator.mul, values)
# Out:
# 29348.0
